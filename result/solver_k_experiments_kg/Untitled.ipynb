# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import os
import argparse

# %%
best_qKG_k5 = np.load('best_qKG_k5.npy')
best_qKG_k10 = np.load('best_qKG_k10.npy')

# %%
fig, ax = plt.subplots()

ax.plot(best_qKG_k5, 'b+-', label = 'qKG-k5')

ax.plot(best_qKG_k10, 'r*-', label = 'qKG-k10')
plt.xlabel('number of iteration')
plt.ylabel('Best value found')
plt.legend()
plt.savefig('policy_comparison_best_results.png')
plt.show()

plt.close()
